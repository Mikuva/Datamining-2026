# %% [markdown]
# # CZSO IKZ – repair / reorder existujících výstupů (v10 robust + display fix)
#
# Notebook nepřegenerovává celý pipeline.
# Použij ho, když už máš hotový `czso_ikz_a_to_z_output` a chceš:
#
# - znovu přerovnat manifest,
# - refreshnout novější jednoleté datasety,
# - znovu zobrazit previewe podle územní úrovně.

# %%
from pathlib import Path
import importlib
import pandas as pd

import czso_ikz_v10_robust_patch
import czso_ikz_territory_patch

importlib.reload(czso_ikz_v10_robust_patch)
importlib.reload(czso_ikz_territory_patch)

from czso_ikz_v10_robust_patch import repair_existing_output
from czso_ikz_territory_patch import display_results_by_territory

BASE_DIR = Path.cwd()
OUTPUT_DIR = BASE_DIR / 'czso_ikz_a_to_z_output'
TARGET_YEARS = [2023, 2024]
FORCE_REDOWNLOAD = False
PAUSE_SECONDS = 0.0
DELETE_DOWNLOADED_FILES_AFTER_PREVIEW = True

DISPLAY_CATEGORIES = None
DISPLAY_SCOPES = None
DISPLAY_LIMIT = None

print('Output dir:', OUTPUT_DIR)
# Out:
# Output dir: C:\Users\jakub.sekanina\projekt_index_kvality_cr\Datamining-2026\czso_ikz_v10_display_fixed_clean_bundle\czso_ikz_a_to_z_output

# %%
manifest_df, results, summary = repair_existing_output(
    OUTPUT_DIR,
    refresh_recent_single_year=True,
    target_years=TARGET_YEARS,
    force_redownload=FORCE_REDOWNLOAD,
    pause_seconds=PAUSE_SECONDS,
    cleanup_downloaded_files=DELETE_DOWNLOADED_FILES_AFTER_PREVIEW,
    persist=True,
)
print('Manifest rows:', len(manifest_df))
summary
# Out:
# C:\Users\jakub.sekanina\projekt_index_kvality_cr\Datamining-2026\czso_ikz_v10_display_fixed_clean_bundle\czso_ikz_v8_clean_patch.py:209: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   working["_has_years_sort"] = working.get("has_target_years", pd.Series(False, index=working.index)).fillna(False).astype(int) * -1
# Manifest rows: 273
# {'removed_historical': 0,
#  'removed_no_preview': 0,
#  'remaining': 273,
#  'notes': ['130141r23: obnoveno full preview pro jednoletý dataset [2022]',
#   '130141r24: obnoveno full preview pro jednoletý dataset [2023]',
#   '140133q22: obnoveno full preview pro jednoletý dataset [2022]',
#   '140133q23: obnoveno full preview pro jednoletý dataset [2023]',
#   '140131q22: obnoveno full preview pro jednoletý dataset [2022]',
# ...

# %%
if 'relevance_pro_IKZ' not in manifest_df.columns and 'relevance_pro_ikz' in manifest_df.columns:
    manifest_df['relevance_pro_IKZ'] = manifest_df['relevance_pro_ikz']

preferred_cols = [
    'order', 'territorial_scope_label', 'category', 'dataset_id', 'dataset_title',
    'relevance_pro_IKZ', 'has_primary_key', 'primary_key_column',
    'has_target_years', 'target_years_present', 'years_sample', 'status'
]
safe_cols = [c for c in preferred_cols if c in manifest_df.columns]
display(manifest_df[safe_cols].head(60))
# Out:
#     order territorial_scope_label category  \
# 0       1                    obec        A
# 1       2                    obec        C
# 2       3                    obec        C
# 3       4                    obec        C
# 4       5                    obec        C
# 5       6                    obec        C
# 6       7                    obec        C
# 7       8                    obec        C
# 8       9                    obec        C
# 9      10                    obec        C
# 10     11                    obec        C
# 11     12                    obec        C
# 12     13                    obec        C
# 13     14                    obec        C
# 14     15                    obec        C
# 15     16                    obec        C
# 16     17                    obec        C
# 17     18                    obec        C
# 18     19                    obec        C
# 19     20                    obec        C
# 20     21                    obec        C
# ...

# %%
display_results_by_territory(
    results,
    categories=DISPLAY_CATEGORIES,
    scopes=DISPLAY_SCOPES,
    max_items=DISPLAY_LIMIT,
)
# Out:
# # Územní úroveň: neurčeno
# ## 001. [A] Dokončené byty v obcích
#                          hodnota
# polozka
# target_years_present  2023, 2024
# has_primary_key             True
# primary_key_column    vuzemi_cis
# **HEAD**
#         idhod  hodnota  stapro_kod  tb_cis  tb_kod  vuzemi_cis  vuzemi_kod  \
# 0  1457433181        2        3103     NaN     NaN          43      539783
# 1  1457432328        2        3103     NaN     NaN          43      532479
# 2  1457433488        1        3103     NaN     NaN          43      551821
# 3  1457431105        0        3103     NaN     NaN          43      559806
# 4  1457433090        3        3103     NaN     NaN          43      574911
#
#     rok   casref_od   casref_do              stapro_txt  tb_txt   vuzemi_txt
# 0  2024  2024-01-01  2024-12-31  Počet dokončených bytů     NaN        Oplot
# 1  2024  2024-01-01  2024-12-31  Počet dokončených bytů     NaN   Kmetiněves
# ...
