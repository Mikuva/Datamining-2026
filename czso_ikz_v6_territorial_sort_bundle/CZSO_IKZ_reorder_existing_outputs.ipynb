# %% [markdown]
# # CZSO IKZ – rychlé přeuspořádání existujících výstupů podle územní úrovně
#
# Tento notebook **nestahuje žádná nová data**. Jen načte už hotový output z `czso_ikz_a_to_z_output`, určí územní úroveň datasetů a přepíše souhrnné soubory v novém pořadí.
#
# Pořadí je: **obec -> ORP -> okres -> kraj -> region soudržnosti -> ČR/stát -> jiné nadobecní celky -> více úrovní -> podobecní**.

# %%
from pathlib import Path
import pandas as pd

from czso_ikz_territory_patch import (
    quick_resort_existing_output,
    display_results_by_territory,
)

BASE_DIR = Path.cwd()
OUTPUT_DIR = BASE_DIR / 'czso_ikz_a_to_z_output'
DISPLAY_LIMIT = None

print('Output dir:', OUTPUT_DIR)
# Out:
# Output dir: C:\Users\jakub.sekanina\projekt_index_kvality_cr\Datamining-2026\czso_ikz_v6_territorial_sort_bundle\czso_ikz_a_to_z_output

# %%
manifest_df, results, territorial_summary = quick_resort_existing_output(
    OUTPUT_DIR,
    persist=True,
)

territorial_summary
# Out:
# C:\Users\jakub.sekanina\projekt_index_kvality_cr\Datamining-2026\czso_ikz_v6_territorial_sort_bundle\czso_ikz_territory_patch.py:559: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   working["_has_pk_sort"] = has_pk_series.fillna(False).astype(int) * -1
# C:\Users\jakub.sekanina\projekt_index_kvality_cr\Datamining-2026\czso_ikz_v6_territorial_sort_bundle\czso_ikz_territory_patch.py:560: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   working["_has_years_sort"] = has_years_series.fillna(False).astype(int) * -1
# ...

# %%
manifest_df[['order', 'territorial_scope_label', 'category', 'dataset_id', 'dataset_title', 'primary_key_column', 'territorial_evidence']].head(40)
# Out:
#     order territorial_scope_label category              dataset_id  \
# 0       1                    obec        A                  200068
# 1       2                    obec        C               140133q25
# 2       3                    obec        C               140131q25
# 3       4                    obec        C               130141r25
# 4       5                    obec        C               140133q24
# 5       6                    obec        C               140131q24
# 6       7                    obec        C               340129r25
# 7       8                    obec        C               250169r24
# 8       9                    obec        C                  190037
# 9      10                    obec        C               130141r24
# 10     11                    obec        C               140133q23
# 11     12                    obec        C               140131q23
# 12     13                    obec        C               340129r24
# ...

# %%
display_results_by_territory(
    results,
    max_items=DISPLAY_LIMIT,
)
# Out:
# # Územní úroveň: obec
# ## 001. [A] Dokončené byty v obcích
#                          hodnota
# polozka
# target_years_present  2023, 2024
# has_primary_key             True
# primary_key_column    vuzemi_cis
# **HEAD**
#         idhod  hodnota  stapro_kod  tb_cis  tb_kod  vuzemi_cis  vuzemi_kod  \
# 0  1457433181        2        3103     NaN     NaN          43      539783
# 1  1457432328        2        3103     NaN     NaN          43      532479
# 2  1457433488        1        3103     NaN     NaN          43      551821
# 3  1457431105        0        3103     NaN     NaN          43      559806
# 4  1457433090        3        3103     NaN     NaN          43      574911
#
#     rok   casref_od   casref_do              stapro_txt  tb_txt   vuzemi_txt
# 0  2024  2024-01-01  2024-12-31  Počet dokončených bytů     NaN        Oplot
# 1  2024  2024-01-01  2024-12-31  Počet dokončených bytů     NaN   Kmetiněves
# ...

# %% [markdown]
# ## Přepsané soubory
#
# Notebook přepíše pouze:
#
# - `ikz_a_to_z_manifest.csv`
# - `ikz_a_to_z_manifest.xlsx`
# - `ikz_a_to_z_previews.md`
# - `datasets_by_territorial_scope.csv`
#
# Samotné soubory v `previews/` zůstávají beze změny.
